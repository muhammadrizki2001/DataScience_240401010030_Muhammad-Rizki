# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadrizki2001/DataScience_240401010030_Muhammad-Rizki/blob/main/Pertemuan1_Muhammad_Rizki_240401010030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pertemuan 1 - Pengenalan Data Science
# Nama: [Muhammad Rziki]
# NIM: [240401010030]
# Kelas: [IF401]

# %% [markdown]
# # ================================================
# # PERTEMUAN 1: Notebook Pertama Data Science
# # ================================================
#
# # SEL 1: Output sederhana
# print("Hello, Data Science!")
# print("Selamat datang di mata kuliah Pengantar Data Science!")
#
# # SEL 2: Variabel dan tipe data dasar
# nama = "Muhammad Rizki"
# angkatan = 2024
# ipk = 4.00
# aktif = True
#
# print(f"Nama : {nama}")
# print(f"Angkatan : {angkatan}")
# print(f"IPK : {ipk}")
# print(f"Aktif : {aktif}")
#
# # SEL 3: List dan perulangan
# tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
#
# print("\nTools Data Science yang akan kita pelajari:")
#
# for i, tool in enumerate(tools, 1):
#     print(f"{i}. {tool}")
#
# # SEL 4: Fungsi sederhana
# def perkenalan(nama, prodi, angkatan):
#     """Fungsi untuk menampilkan perkenalan mahasiswa."""
#     return f"Hai! Saya {Muhammad Rizki} dari {Informatika}, angkatan {2024}."
#
# hasil = perkenalan(
#     "Muhammad Rizki",
#     "Informatika",
#     2024
# )
#
# print(hasil)
#
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Lady Kimiel
# Angkatan : 2024
# IPK : 4.0
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub
# Hai! Saya Muhammad Rizki dari Informatika, angkatan 2024.
# Kesimpulan
# Pada praktikum ini saya mempelajari pengenalan Data Science serta berbagai tools yang digunakan dalam proses pembelajarannya. Saya juga belajar menjalankan kode Python sederhana menggunakan Google Colab, mulai dari penggunaan variabel, tipe data, perulangan, hingga fungsi.
#
# Dari praktikum ini, saya mendapatkan pemahaman awal mengenai lingkungan kerja dan dasar pemrograman yang akan menjadi bekal untuk mempelajari materi Data Science pada pertemuan berikutnya.
