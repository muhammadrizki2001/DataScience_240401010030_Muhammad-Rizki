# %% [markdown]
# Nama : Muhammad Rizki Nim : 240401010030 Kelas : IF401

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

print("--- Data Berhasil Dimuat ---")
display(df.head())
# Out:
# --- Data Berhasil Dimuat ---
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# Q1: JUMLAH BARIS, KOLOM, DAN NAMA KOLOM

# %%
print("Struktur Data:")
rows, cols = df.shape
print(f"Jumlah Baris: {rows}")
print(f"Jumlah Kolom: {cols}")
print(f"Daftar Nama Kolom : {df.columns.tolist()}")
# Out:
# Struktur Data:
# Jumlah Baris: 891
# Jumlah Kolom: 12
# Daftar Nama Kolom : ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# Q2: MISSING VALUES (JUMLAH & PERSENTASE)

# %%
print("Analisis Missing Values:")
missing_data = pd.DataFrame({
    'Missing': df.isnull().sum(),
    'Persentase (%)': (df.isnull().sum() / len(df)) * 100
})
display(missing_data[missing_data['Missing'] > 0])
# Out:
# Analisis Missing Values:
#           Missing  Persentase (%)
# Age           177       19.865320
# Cabin         687       77.104377
# Embarked        2        0.224467

# %% [markdown]
# Q3: PERSENTASE PENUMPANG SELAMAT

# %%
survival_rate = df['Survived'].mean() * 100
print(f"\n[Q3] Persentase Penumpang Yang Selamat: {survival_rate:.2f}%")
# Out:
# [Q3] Persentase Penumpang Yang Selamat: 38.38%

# %% [markdown]
# Q4: FILTER WANITA KELAS 1 (PCLASS=1)

# %%
female_c1 = df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]
jml_female_c1 = len(female_c1)
avg_age_female_c1 = female_c1['Age'].mean()

print(f" Analisis Wanita Kelas 1:")
print(f"- Jumlah Penumpang: {jml_female_c1}")
print(f"- Rata-rata Usia  : {avg_age_female_c1:.2f} tahun")
# Out:
#  Analisis Wanita Kelas 1:
# - Jumlah Penumpang: 94
# - Rata-rata Usia  : 34.61 tahun

# %% [markdown]
# Q5: TINGKAT KESELAMATAN PER KELAS

# %%
print("Tingkat Keselamatan Berdasarkan Kelas:")
class_survival = df.groupby('Pclass')['Survived'].mean() * 100
print(class_survival)
print(f"Kelas dengan tingkat keselamatan tertinggi: Kelas {class_survival.idxmax()}")
# Out:
# Tingkat Keselamatan Berdasarkan Kelas:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64
# Kelas dengan tingkat keselamatan tertinggi: Kelas 1

# %% [markdown]
# Q6: ANALISIS TAMBAHAN (KESELAMATAN BERDASARKAN JENIS KELAMIN)

# %%
print("Analisis Tambahan (Gender vs Survival):")
gender_survival = df.groupby('Sex')['Survived'].mean() * 100
print(gender_survival)
# Out:
# Analisis Tambahan (Gender vs Survival):
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %% [markdown]
# Apa yang Dipelajari : Dasar analisis data menggunakan Pandas pada dataset Titanic: memuat data, melihat struktur data, missing value, filtering, grouping, dan agregasi.

# %% [markdown]
# Temuan : Perempuan dan penumpang kelas 1 memiliki tingkat keselamatan lebih tinggi.

# %% [markdown]
# Keterbatasan : Belum ada visualisasi dan analisis statistik lanjutan.
